# %% [markdown]
# # Info
# (C) convention, for programming standard violation
#
# (R) refactor, for bad code smell
#
# (W) warning, for python specific problems
#
# (E) error, for much probably bugs in the code
#
# (F) fatal, if an error occurred which prevented pylint from doing
#
# [source](https://pylint.pycqa.org/_/downloads/en/pylint-2.1.0/pdf/)
#
# http://pylint-messages.wikidot.com/all-codes
#
# https://pycodequ.al/docs/pylint-messages.html

# %% [markdown]
# # Environment configuration

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from pylab import rcParams
palette_color = 'Blues_r'
colors = sns.color_palette(palette_color, as_cmap=True)
sns.set()
pd.set_option('display.max_rows', 100)
# Out:
# /home/ndc/repos/GithubPythonCodeSmellCrawler/src/env/lib/python3.9/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
X0 = 6
Y0 = 4

X1 = 9
Y1 = 6

X2 = 12
Y2 = 9

X3 = 15
Y3 = 12

category_map = {'W':'Warning', 'R':'Refactor','C':'Convention'}

# %%
def set_plot_size(w, h):
        rcParams['figure.figsize'] = w, h

def reset_plot_size():
    set_plot_size(X1,Y1)

def make_url(row):
    gh = 'https://github.com/'
    file = row.filename.split('/')[1]
    url = f'{gh}/{row.repo}/tree/{row.commit}/{file}'
    return url

def barplot(d, x, y, **kwargs):
    plot = sns.barplot(data=d,x=x,y=y,ax=kwargs.get('ax'), hue = kwargs.get('hue'))
    plot.set_xlabel(kwargs.get('x_label'))
    plot.set_ylabel(kwargs.get('y_label'))
    plot.set_title(kwargs.get('title'))
    return plot

def violinplot(d, **kwargs):
    plot = sns.violinplot(data=d, cut=0,inner='quartile',ax=kwargs.get('ax'))    
    plot.set_xlabel(kwargs.get('x_label'))
    plot.set_ylabel(kwargs.get('y_label'))
    plot.set_title(kwargs.get('title'))
    return plot

reset_plot_size()

# %%
df = pd.read_parquet('data.parquet')
df = df.loc[df.symbol != 'fatal']
df = df.loc[df.linter == 'pylint']
df = df.reset_index(drop=True)

# %%
df

# %% [markdown]
# # Data preparation

# %%
df.filename = df.filename.apply(lambda x: x.replace('dumps/',''))
df = df.loc[df.type.isin(['W','C','R'])]

# %% [markdown]
# ## Mark relevant pitfalls

# %%
detected_pitfalls = df.number.unique()
all_codes = pd.read_csv('codes.csv')
relevant_codes = all_codes.loc[all_codes.code.isin(detected_pitfalls)]
relevant_codes = relevant_codes.loc[relevant_codes.is_pitfall != 0]

#Lists if an unnanoted pitfall was detected
relevant_codes.loc[relevant_codes.is_pitfall != 1].reset_index(drop=True)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, code, symbol, is_pitfall]
# Index: []

# %%
relevant_codes = relevant_codes.loc[relevant_codes.is_pitfall == 1].reset_index(drop = True)
relevant_codes.drop(columns = ['is_pitfall']).to_csv('relevant_codes.csv', index=False)

# %%
df = df.loc[df.number.isin(relevant_codes.code)].reset_index(drop=True)

# %%
#df['url'] = df.apply(make_url, axis=1)
w = df.loc[df.type == 'W']
c = df.loc[df.type == 'C']
r = df.loc[df.type == 'R']

# %% [markdown]
# # Data overview

# %%
amount_repos = len(df.repo.unique())
print(f'Total of repositories analyzed: {amount_repos}')
# Out:
# Total of repositories analyzed: 213

# %% [markdown]
# ## Distribution by kind of flaw

# %% [markdown]
# ## Code counts

# %%
counts = df.number.value_counts().reset_index()
counts = counts.rename(columns = {'index':'number', 'number':'counts'})

descriptions = df.groupby('number').head(1)[['number','symbol']]

counts = counts.merge(descriptions, on='number')[['number','symbol','counts']]
counts = counts.sort_values(by=['counts'],ascending=False).reset_index(drop=True)
counts
# Out:
#    number                          symbol  counts
# 0   W0201  attribute-defined-outside-init     518
# 1   R1732             consider-using-with     452
# 2   R0801                  duplicate-code     444
# 3   W0622               redefined-builtin     202
# 4   W0401                 wildcard-import     124
# 5   C0121            singleton-comparison     121
# 6   R1710  inconsistent-return-statements     103
# 7   C0200        consider-using-enumerate      70
# 8   R1714               consider-using-in      40
# 9   W0102         dangerous-default-value      39
# 10  R0912               too-many-branches      15
# 11  R1707            trailing-comma-tuple      14
# 12  C1801                len-as-condition      11
# 13  W0221                arguments-differ       8
# 14  R0123              literal-comparison       6

# %%
df.repo.unique()
# Out:
# array(['amueller/word_cloud', 'ultralytics/yolov5', 'pyodide/pyodide',
#        'instillai/deep-learning-roadmap',
#        'dennybritz/cnn-text-classification-tf', 'kholia/OSX-KVM',
#        '0x5e/wechat-deleted-friends', 'django-tastypie/django-tastypie',
#        'hwalsuklee/tensorflow-generative-model-collections',
#        'conda/conda', 'NVIDIA/pix2pixHD', 'jina-ai/jina', 'lebinh/ngxtop',
#        'cython/cython', 'quantopian/zipline', 'yunjey/stargan',
#        'python/cpython', 'seatgeek/fuzzywuzzy', 'geekcomputers/Python',
#        'jadore801120/attention-is-all-you-need-pytorch',
#        'Netflix/security_monkey', 'tkarras/progressive_growing_of_gans',
#        'nate-parrott/Flashlight', 'EleutherAI/gpt-neo', 'numpy/numpy',
#        'anishathalye/neural-style', 'gevent/gevent', 'iterative/dvc',
#        'EssayKillerBrain/EssayKiller_V2', 'wistbean/learn_python3_spider',
#        'spyder-ide/spyder', 'getsentry/sentry', 'docker/docker-py',
#        'JakeWharton/pidcat', 'ultralytics/yolov3', 'zalando/connexion',
#        'quantumblacklabs/kedro', 'ajalt/fuckitpy', 'dpkp/kafka-python',
#        'dmlc/gluon-cv', 'powerline/powerline', 'chatopera/Synonyms',
#        '3b1b/manim', 'facebookresearch/ParlAI',
#        'lengstrom/fast-style-transfer', 'worldveil/dejavu',
#        'Morizeyao/GPT2-Chinese', 'giampaolo/psutil',
#        'milesial/Pytorch-UNet', 'EpistasisLab/tpot',
#        'hardikvasa/google-images-download', 'skorch-dev/skorch',
#        'pandas-dev/pandas', 'ricequant/rqalpha', 'adamian98/pulse',
#        'postmanlabs/httpbin', 'deepfakes/faceswap', 'xuebinqin/U-2-Net',
#        'binux/pyspider', 'lauris/awesome-scala', 'kivy/kivy',
#        'YadiraF/PRNet', 'alteryx/featuretools', 'beetbox/beets',
#        'encode/django-rest-framework', 'wangshub/wechat_jump_game',
#        'waditu/tushare', 'wting/autojump', 'open-mmlab/mmdetection',
#        'NVIDIA/FastPhotoStyle', 'facebookresearch/DrQA',
#        'alirezamika/autoscraper', 'thumbor/thumbor', 'python/mypy',
#        'horovod/horovod', 'domlysz/BlenderGIS', 'rossant/awesome-math',
#        'pytorch/tutorials', 'Cadene/pretrained-models.pytorch',
#        'saltstack/salt', 'spulec/moto', 'rushter/data-science-blogs',
#        'kovidgoyal/kitty', 'rushter/MLAlgorithms', 'ReFirmLabs/binwalk',
#        'tflearn/tflearn', 'kuangliu/pytorch-cifar',
#        'jwyang/faster-rcnn.pytorch', 'PaddlePaddle/PaddleOCR',
#        'scikit-learn/scikit-learn', 'frostming/legit', 'thunil/TecoGAN',
#        'cupy/cupy', 'Jack-Cherish/python-spider', 'amperser/proselint',
#        'reorx/httpstat', 'python-poetry/poetry', 'shobrook/rebound',
#        'dylanaraps/pywal', 'bokeh/bokeh', 'vt-vl-lab/3d-photo-inpainting',
#        'zihangdai/xlnet', 'sympy/sympy', 'ipython/ipython',
#        'magic-wormhole/magic-wormhole',
#        'CorentinJ/Real-Time-Voice-Cloning', 'beurtschipper/Depix',
#        'pyca/cryptography', 'ludwig-ai/ludwig', 'MagicStack/uvloop',
#        'huggingface/transformers', 'mitmproxy/mitmproxy', 'liuwons/wxBot',
#        'chainer/chainer', 'fabric/fabric', 'python-visualization/folium',
#        'QUANTAXIS/QUANTAXIS', 'modin-project/modin', 'python-trio/trio',
#        'gregmalcolm/python_koans', 's0md3v/XSStrike',
#        'equinusocio/material-theme', 'psf/requests-html',
#        'flask-admin/flask-admin', 'stamparm/maltrail',
#        'Rapptz/discord.py', 'numenta/nupic', 'rq/rq',
#        'django-crispy-forms/django-crispy-forms', 'scrapy/scrapy',
#        'apache/airflow', 'encode/apistar', 'stewartmcgown/uds',
#        'psf/requests', 'ansible/awx', 'clips/pattern',
#        'Uberi/speech_recognition', 'microsoft/nni', 'tzutalin/labelImg',
#        'nicolargo/glances', 'burnash/gspread', 'StevenBlack/hosts',
#        'axi0mX/ipwndfu', 'fossasia/visdom', 'vaexio/vaex',
#        'amdegroot/ssd.pytorch', 'dbcli/mycli', 'sivel/speedtest-cli',
#        'scipy/scipy', 'dbcli/pgcli', 'rwightman/pytorch-image-models',
#        'encode/uvicorn', 'plotly/dash', 'robotframework/robotframework',
#        'soimort/you-get', 'junyanz/iGAN', 'longld/peda',
#        'alexjc/neural-enhance', 'anishathalye/dotbot', 'n1nj4sec/pupy',
#        'zalando/patroni', 'Zulko/moviepy',
#        'naturomics/CapsNet-Tensorflow', 'coleifer/peewee',
#        'django-cms/django-cms', 'hindupuravinash/the-gan-zoo',
#        'lukemelas/EfficientNet-PyTorch',
#        'nl8590687/ASRT_SpeechRecognition', 'microsoft/cascadia-code',
#        'pyinstaller/pyinstaller', 'matplotlib/matplotlib',
#        'mkdocs/mkdocs', 'fail2ban/fail2ban', 'sanic-org/sanic',
#        'NVlabs/stylegan2', 'explosion/spaCy', 'martinblech/xmltodict',
#        'facebookresearch/detectron2', 'streamlink/streamlink',
#        'flairNLP/flair', 'PeterL1n/BackgroundMattingV2',
#        'smicallef/spiderfoot', 'microsoft/DeepSpeed',
#        'great-expectations/great_expectations', 'mxrch/GHunt',
#        'lyst/lightfm', 'eriklindernoren/ML-From-Scratch',
#        'pjialin/py12306', 'navdeep-G/samplemod', 'MVIG-SJTU/AlphaPose',
#        'kovidgoyal/calibre', 'falconry/falcon', 'Theano/Theano',
#        'mstamy2/PyPDF2', 'spyoungtech/grequests', 'allenai/allennlp',
#        'aws/aws-cli',
#        'eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee/eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee',
#        'oppia/oppia', 'NVlabs/stylegan', 'awslabs/aws-shell',
#        'stanfordnlp/stanza', 'ddbourgin/numpy-ml',
#        'karpathy/arxiv-sanity-preserver', 'statsmodels/statsmodels',
#        'ytdl-org/youtube-dl', 'tychxn/jd-assistant', 'mlflow/mlflow',
#        'alexjc/neural-doodle', 'nltk/nltk', 'celery/celery',
#        'mher/flower', 'benoitc/gunicorn'], dtype=object)

# %%
set_plot_size(X2,Y2)

code_counts = df.number.value_counts().reset_index()
code_counts.columns = ['code', 'count']
code_counts = code_counts.sort_values(by='count', ascending=True)
code_counts = code_counts.reset_index(drop=True)

fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2)


fig.suptitle('Overview into the analyzed data.')
#General violinplot
violinplot(code_counts['count'].values,
           title = 'Distribution of the pitfalls.',
           y_label = 'Distribution',           
           ax = ax0
          )
ax0.set_xticks([])

#Category barplot
category_counts = df.type.value_counts().reset_index()
category_counts.columns = ['category','count']
category_counts.category = category_counts.category.apply(lambda x : category_map[x])
barplot(category_counts,
        x = 'category',
        y = 'count',
        y_label = 'Count',
        title = 'Amount of pitfalls into each category.',
        hue = 'category',
        ax = ax1
       )
ax1.set_yticklabels([])
ax1.set_xticklabels([])

#General barplot
barplot(code_counts,
        x = 'code',
        y_label = 'Count',
        x_label = 'Pitfall codes',
        y = 'count',
        title = 'Individual amount of pitfalls by code.',
        ax=ax2
       )
ax2.set_xticks([])


#Zoom barplot
amount = 8
bigger = code_counts.tail(amount)
right = barplot(bigger,
                x = 'code',
                y = 'count',
                y_label = 'Count',
                title = f'Zoom-in on the top {amount} pitfalls.',
                ax = ax3
               )
ax3.tick_params(axis = 'x', labelrotation = 45 )
ax3.set_yticklabels([])
# Out:
# [Text(0, 0.0, ''),
#  Text(0, 100.0, ''),
#  Text(0, 200.0, ''),
#  Text(0, 300.0, ''),
#  Text(0, 400.0, ''),
#  Text(0, 500.0, ''),
#  Text(0, 600.0, '')]

# %% [markdown]
# # Playground

# %%
df.loc[df.number == 'W0201']
# Out:
#      type      module                               obj  lnum  col  \
# 0       W  versioneer              get_config_from_root   352    4
# 1       W  versioneer              get_config_from_root   353    4
# 2       W  versioneer              get_config_from_root   354    4
# 3       W  versioneer              get_config_from_root   355    4
# 4       W  versioneer              get_config_from_root   356    4
# ...   ...         ...                               ...   ...  ...
# 2157    W      doodle               NeuralGenerator.run   626   28
# 2158    W      doodle               NeuralGenerator.run   616   16
# 2162    W       setup         pytest.initialize_options   143    8
# 2165    W       setup  PyTestCommand.initialize_options    56    8
# 2166    W       setup    PyTestCommand.finalize_options    63    8
#
#            filename                          symbol  \
# 0     versioneer.py  attribute-defined-outside-init
# 1     versioneer.py  attribute-defined-outside-init
# 2     versioneer.py  attribute-defined-outside-init
# 3     versioneer.py  attribute-defined-outside-init
# 4     versioneer.py  attribute-defined-outside-init
# ...             ...                             ...
# 2157      doodle.py  attribute-defined-outside-init
# 2158      doodle.py  attribute-defined-outside-init
# 2162       setup.py  attribute-defined-outside-init
# 2165       setup.py  attribute-defined-outside-init
# 2166       setup.py  attribute-defined-outside-init
#
#                                                    text number  linter  \
# 0              Attribute 'VCS' defined outside __init__  W0201  pylint
# 1            Attribute 'style' defined outside __init__  W0201  pylint
# 2     Attribute 'versionfile_source' defined outside...  W0201  pylint
# 3     Attribute 'versionfile_build' defined outside ...  W0201  pylint
# 4       Attribute 'tag_prefix' defined outside __init__  W0201  pylint
# ...                                                 ...    ...     ...
# 2157     Attribute 'iteration' defined outside __init__  W0201  pylint
# 2158    Attribute 'seed_image' defined outside __init__  W0201  pylint
# 2162   Attribute 'pytest_args' defined outside __init__  W0201  pylint
# 2165           Attribute 'cov' defined outside __init__  W0201  pylint
# 2166    Attribute 'test_suite' defined outside __init__  W0201  pylint
#
#       lines_amount                                    commit  \
# 0             1823  0b3b942f58337aa3d4e0429d45e59175bb573eca
# 1             1823  0b3b942f58337aa3d4e0429d45e59175bb573eca
# 2             1823  0b3b942f58337aa3d4e0429d45e59175bb573eca
# 3             1823  0b3b942f58337aa3d4e0429d45e59175bb573eca
# 4             1823  0b3b942f58337aa3d4e0429d45e59175bb573eca
# ...            ...                                       ...
# 2157           659  b2fac92b27dea18cf1ab8438c981b3537fa9ad06
# 2158           659  b2fac92b27dea18cf1ab8438c981b3537fa9ad06
# 2162           200  98fdcd749b0c4d3ec1ad0cfae058d193595413e1
# 2165           123  1299ea9e967a61ae2edebe191082fd169b864c64
# 2166           123  1299ea9e967a61ae2edebe191082fd169b864c64
#
#                       repo
# 0      amueller/word_cloud
# 1      amueller/word_cloud
# 2      amueller/word_cloud
# 3      amueller/word_cloud
# 4      amueller/word_cloud
# ...                    ...
# 2157  alexjc/neural-doodle
# 2158  alexjc/neural-doodle
# 2162         celery/celery
# 2165      benoitc/gunicorn
# 2166      benoitc/gunicorn
#
# [518 rows x 13 columns]
